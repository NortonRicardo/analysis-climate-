# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Exemplos read file
# pd.read_parquet('data/train/station_neighbors.parquet')
# pd.read_csv('train/neighbors/results/neighbors_metrics.csv')

# %%
# measurement_time	code	n	n1	n1_dist	n1_alt_diff	n1_idw	n2	n2_dist	n2_alt_diff	n2_idw	n3	n3_dist	n3_alt_diff	n3_idw	n4	n4_dist	n4_alt_diff	n4_idw	n5	n5_dist	n5_alt_diff	n5_idw	n6	n6_dist	n6_alt_diff	n6_idw	n7	n7_dist	n7_alt_diff	n7_idw	n8	n8_dist	n8_alt_diff	n8_idw	n9	n9_dist	n9_alt_diff	n9_idw	n10	n10_dist	n10_alt_diff	n10_idw	n11	n11_dist	n11_alt_diff	n11_idw	n12	n12_dist	n12_alt_diff	n12_idw	n13	n13_dist	n13_alt_diff	n13_idw	n14	n14_dist	n14_alt_diff	n14_idw	n15	n15_dist	n15_alt_diff	n15_idw	n16	n16_dist	n16_alt_diff	n16_idw	n17	n17_dist	n17_alt_diff	n17_idw	n18	n18_dist	n18_alt_diff	n18_idw	n19	n19_dist	n19_alt_diff	n19_idw	n20	n20_dist	n20_alt_diff	n20_idw
df = pd.read_parquet('data/data_train/temperature/temperature_train.parquet')

# %%
df
# Out:
#             measurement_time  code         n        n1   n1_dist  n1_alt_diff  \
# 0        2002-12-19 14:00:00  A002  0.710332  0.697802  0.072745     0.493745
# 1        2002-12-19 14:00:00  A003  0.695572  0.712454  0.072745     0.507058
# 2        2002-12-19 14:00:00  A404  0.682657  0.650183  0.278231     0.388400
# 3        2002-12-19 14:00:00  A506  0.680812  0.728938  0.204640     0.628206
# 4        2002-12-19 14:00:00  A601  0.704797  0.683150  0.018730     0.506837
# ...                      ...   ...       ...       ...       ...          ...
# 42315840 2025-12-31 23:00:00  S729  0.642066  0.703297  0.047550     0.500049
# 42315841 2025-12-31 23:00:00  S731  0.702952  0.598901  0.036554     0.366536
# 42315842 2025-12-31 23:00:00  S733  0.623616  0.630037  0.034862     0.475219
# 42315843 2025-12-31 23:00:00  S734  0.584871  0.617216  0.053954     0.513096
# 42315844 2025-12-31 23:00:00  S736  0.625461  0.620879  0.031539     0.510438
#
# ...

# %%
# cols = ["variable", "mae", "rmse", "bias", "r", "r2"]
# result_linear_regression = pd.read_csv('train/linear_regression/results/linear_regression_metrics.csv')[cols]
# result_neighbors = pd.read_csv('train/neighbors/results/neighbors_metrics.csv')[cols]
# result_dense = pd.read_csv('train/dense/results/dense_metrics.csv')[cols]
# result_neighbors
# Out:
#       variable       mae      rmse      bias         r        r2
# 0  temperature  0.033761  0.046718 -0.000930  0.900751  0.800841
# 1     humidity  0.092140  0.126838  0.001290  0.837802  0.676401
# 2    radiation  0.004502  0.009925 -0.000022  0.888307  0.777155
# 3     pressure  0.074112  0.123212 -0.005021  0.684029  0.353605

# %% [markdown]
# Teste
